# %% [markdown]
# <a href="https://colab.research.google.com/github/pri-2711/qiskit_codes/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
